# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
g = 9.80665 # ускорение свободного падения
v0 = 800 # начальная скорость пули
h0 = 2 # высота, на которой закреплено ружьё
n = 100 # кол-во попыток
sigma = 20

# %%
t0 = math.sqrt(2*h0/g)
S0 = v0*t0;
S = np.random.normal(S0,sigma,n)
V = S*(1/math.sqrt(2*h0/g))

# %%
Vmin = min(V)
Vmax = max(V)
x = np.arange(Vmin, Vmax + (Vmax-Vmin)/10, (Vmax-Vmin)/10) # диапазон с заданным шагом
print("Vmin:", Vmin, "Vmax:", Vmax)
plt.title("Нормальное распределение скоростей") # заголовок
plt.xlabel("V") # ось абсцисс
plt.ylabel("Count") # ось ординат
plt.grid() # включение отображение сетки
a = plt.hist(V, x)
# Out:
# Vmin: 705.5546040303412 Vmax: 882.7432612683441

# %%
plt.title("Зависимость расстояния S от начальной скорости V") # заголовок
plt.xlabel("S") # ось абсцисс
plt.ylabel("V") # ось ординат
plt.grid() # включение отображение сетки
a = plt.plot(S,V,'y',S,V,'ob') # построение графика
a = plt.plot(S0,v0,'*r') # идеальные v и s

# %%
meanV = np.mean(V) # мат.ожидание/среднее
stdV = np.std(V) # среднеквадратичное (стандартное) отклонение
disV = stdV**2 # дисперсия
print("meanV:", meanV, "\nstdV:", stdV, "\ndisV:", disV)

sum = 0
for i in range(n):
    sum = sum + abs(S0-S[i]) * abs(S0-S[i])
dS = math.sqrt(sum/n)
errS = dS/S0 * 100
print("errS:", int(errS), "%")
# Out:
# meanV: 797.2365661965781
# stdV: 33.161024826497965
# disV: 1099.6535675436144
# errS: 4 %
